# %% [markdown]
# <a href="https://colab.research.google.com/github/Shraddha6999/PLAY-STORE-APP-REVIEW-ANALYSIS/blob/main/PLAY_STORE_APP_REVIEW_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - PLAY STORE APP REVIEW ANALYSIS

# %% [markdown]
# \##### **Project Type** - EDA
# ##### **Contribution** - Individual
# ##### **Team Member 1 -**  Shraddha Chandurkar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The google play store is one of the largest and most popular Android app stores. It serves as the official app store for the Android operating system, allowing user to browse and download applications developed with the Android software development kit and published through Google. It has an enormous amount of data that can be used to make an optimal model. I have tried to perform Data Analysis and prediction into the Google Play store application dataset that I have collected.
#
# This data set contains 13 different features that can be used for predicting whether an app will be successful or not using different features. Along with play store data we have user review data which contains 5 different feature.
#
# Our Analysis is divided into three phases: Data extraction, Data cleaning, Data visualization.
#
# First, we collect the data from the website. In the next step, we try to do data cleaning on the data set to reduce the error percentage. After the data set is ready, we try to analyse the data set using different plots and remove the stuff not needed from the data set. Finally, we narrate the analysis results to provide a clear vision of the relationship among the areas of interest. We include a detailed discussion of the applicability and future research directions in the last section called Conclusion and Solution to Business Objective.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Shraddha6999

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Developer develop Android apps & release on Play Store. As an Developer or say Business Perspective it’s very important to know whether users are enjoying the app or facing any issues. To know this Play Store has a Ratings & reviews section for each app released on play store. Users can submit the ratings and has a freedom to write a review for a particular app. This approach is quite a lengthy to rate & review app i.e. navigate to Play store to submit feedback or redirect leaving a current app workflow to open Play Store App link using URI. We never wanted our customers to leave our application, but with this flow, we are forced to redirect the control to Play store app.
#
# We trust versatile application clients consider online application surveys as a noteworthy impact for paid applications. It is trying for a potential client to peruse all the literary remarks and rating to settle on a choice. Additionally, application engineers experience issues in discovering how to improve the application execution dependent on generally speaking evaluations alone and would profit by understanding a huge number of printed remarks.
#
# 1) What is the most common type of application available on the Play Store?
#
# 2) How does the price of an application affect its rating?
#
# 3) What is the distribution of app prices?
#
# 4) What are some of the most expensive apps?
#
# 5) What categories do the most expensive applications belong to?
#
# 6) How does the size of an app affect its rating?
#
# 7) How are the price, size, and cost of an app related?
#
# 8) What is the minimum and maximum price for an app?
#
# 9) What is the typical rating of an app?
#
# 10) How do reviews influence the rating of an app?
#
# 11) What category of apps receive the most reviews?
#
# 12) Which category of apps have the highest number of installations?
#
# 13) What are the most popular categories on the Play Store?
#
# 14) Which apps have received the most reviews?
#
# 15) How is sentiment polarity varying for paid and free apps?
#
# 16) What is the percentage of review sentiments?
#
# 17) Which category of apps have the most positive reviews?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.
#
# Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
#
# Explore and analyze the data to discover key factors responsible for app engagement and success.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from datetime import datetime
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing Play Store App Review Dataset
df=pd.read_csv('/content/drive/MyDrive/AlmaBetter/Module_1_Python/EDA project data/Play Store Data.csv')

# %%
# Importing Play Store App Sentiment Data ## Customer Review Data
df2=pd.read_csv('/content/drive/My Drive/AlmaBetter/Module_1_Python/EDA project data/User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Plya Store Dataset size")
print("Rows {} Columns {}".format(df.shape[0], df.shape[1]))
# Out:
# Plya Store Dataset size
# Rows 10841 Columns 13

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 483

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(df.isnull(), cbar=False)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The task is to analyze the competition in the Android market using data on play store applications. The data includes 13 features, some with null values and with data type set as object, which needs to be converted to float.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **PLAYSTORE APP DATA**
#
# This file contains data on the Google Play applications. It has 10,841 rows of data with the following columns:
#
# App Category: Category of the app. This could be beauty, business, entertainment, education...etc.
#
# Rating: How users rate the app out of 5, with 1 being the lowest rating and 5 being the highest.
#
# Reviews: The number of user reviews each app has received.
#
# Size: The memory size needed to install the application.
#
# Installs: The number of times each application has been installed by users.
#
# Type: Whether the app is free or a paid app.
#
# Price: The price of the app.
#
# Content Rating: This column specifies the intended audience for the app. Can be for teens, mature audience, or everyone.
#
# Genres: The sub-category for each app. Example: for the Education category, this could be Education: Pretend Play, for example.
#
# Last Updated: Release date of the most recent update for the app.
#
# Current Ver: The app's current version.
#
# Android Ver: The oldest version of Android OS supported by the app.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 6002 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 120 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2832 .
# No. of unique values in  Android Ver is 33 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
#  **CLEANING THE DATA**

# %% [markdown]
# **A) CHECKING DATATYPE**

# %%
print("Columns and data types")
pd.DataFrame(df.dtypes).rename(columns = {0:'dtype'})
# Out:
# Columns and data types
#                   dtype
# App              object
# Category         object
# Rating          float64
# Reviews          object
# Size             object
# Installs         object
# Type             object
# Price            object
# Content Rating   object
# Genres           object
# Last Updated     object
# Current Ver      object
# Android Ver      object

# %% [markdown]
# **1) REVIEWS**

# %%
df["Reviews"].value_counts()
# Out:
# 0         596
# 1         272
# 2         214
# 3         175
# 4         137
#          ...
# 342912      1
# 4272        1
# 5517        1
# 4057        1
# 398307      1
# Name: Reviews, Length: 6002, dtype: int64

# %%
reviews = [i for i in df['Reviews']]
def cleaning_review_data(Reviews_list):
  '''
  This Function Converts DataType From Object To Float
  '''
  cleaned_data = []
  for review in Reviews_list:
     if 'M' in review:
       review = review.replace('M','')
       review = float(review)*1000000
     cleaned_data.append(review)
  return cleaned_data     

df['Reviews']=cleaning_review_data(reviews)
df['Reviews']=df['Reviews'].astype(float)   
df['Reviews'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **2) SIZE**

# %%
df["Size"].value_counts()
# Out:
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 429k                     1
# 200k                     1
# 460k                     1
# 728k                     1
# 619k                     1
# Name: Size, Length: 462, dtype: int64

# %%
newSize = []
for row in df.Size:
    newrow = row[:-1]
    try:
        newSize.append(float(newrow))
    except:
        newSize.append(0) 
    
df.Size = newSize          #Sizes of applications are converted from string to integer format
df['Size'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **3) INSTALLS**

# %%
df["Installs"].value_counts()
# Out:
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: Installs, dtype: int64

# %%
df['Installs'] = df.Installs.str.replace(",","")
df['Installs'] = df.Installs.str.replace("+","")
df['Installs'] = df.Installs.replace("Free",np.nan)
df['Installs'] = df['Installs'].astype(float)
df['Installs'].dtype
# Out:
# <ipython-input-53-b9a734f657b2>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Installs'] = df.Installs.str.replace("+","")
# dtype('float64')

# %% [markdown]
# **4) PRICE**

# %%
df["Price"].value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: Price, Length: 93, dtype: int64>

# %%
df['Price'] = df.Price.replace("Everyone",np.nan)
df['Price'] = df.Price.str.replace("$","").astype(float)
df['Price'].dtype
# Out:
# <ipython-input-55-0e7b0be54ca6>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df.Price.str.replace("$","").astype(float)
# dtype('float64')

# %%
df.describe()
# Out:
#             Rating       Reviews          Size      Installs         Price
# count  9367.000000  1.084100e+04  10841.000000  1.084000e+04  10840.000000
# mean      4.193338  4.443887e+05     31.241500  1.546434e+07      1.027368
# std       0.537431  2.927728e+06     91.801512  8.502936e+07     15.949703
# min       1.000000  0.000000e+00      0.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01      3.100000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03     10.000000  1.000000e+05      0.000000
# 75%       4.500000  5.479800e+04     28.000000  5.000000e+06      0.000000
# max      19.000000  7.815831e+07   1020.000000  1.000000e+09    400.000000

# %% [markdown]
# **B) HANDLING NULL VALUES**

# %%
table=pd.DataFrame(index=df.columns)
table["datatype"]=df.dtypes
table["not null values"]=df.count()
table["null value"]=df.isnull().sum()
 # table["% of the null value"]=df.isnull().mean()
 # table["unique count"]=df.nunique()
table
# Out:
#                datatype  not null values  null value
# App              object            10841           0
# Category         object            10841           0
# Rating          float64             9367        1474
# Reviews         float64            10841           0
# Size            float64            10841           0
# Installs        float64            10840           1
# Type             object            10840           1
# Price           float64            10840           1
# Content Rating   object            10840           1
# Genres           object            10841           0
# Last Updated     object            10841           0
# Current Ver      object            10833           8
# Android Ver      object            10838           3

# %% [markdown]
# **1) RATING**

# %%
df[df['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#        Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
# The "Rating" column has 1474 rows with null values. 
# To handle this, instead of dropping the rows, we will replace the null values with the median of the available values.

df['Rating'].fillna(value=df['Rating'].median(),inplace=True)

# %%
# Verifying the results with a cross-check.

df['Rating'].isnull().sum()
# Out:
# 0

# %%
# Sanity Check

# A sanity check was performed to ensure that the number of reviews was not greater than the number of installations. 
# As only those who have installed the app can provide a review.

# %%
df.loc[df['Rating'] > df['Installs']]
# Out:
#                                                      App           Category  \
# 649                          Healthy Relationships Guide             DATING
# 652                                              PlusOne             DATING
# 2422                                           Visualmed            MEDICAL
# 2425   Be the Expert in Phlebotomy - Professional Nur...            MEDICAL
# 2454                                 KBA-EZ Health Guide            MEDICAL
# ...                                                  ...                ...
# 10701                                          F-O-Meter             FAMILY
# 10708                                        Custos F.O.           BUSINESS
# 10745                                            FP Boss            FINANCE
# 10764                                  FP Transportation  AUTO_AND_VEHICLES
# 10775                                 FQ - Football Quiz             SPORTS
#
# ...

# %%
# Removing the values that failed the sanity check.

temp_data = df.loc[df['Rating'] > df['Installs']].index
df.drop(labels=temp_data,inplace=True)

# %%
# Verifying the results with a cross-check.

df.loc[df['Rating'] > df['Installs']]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **2) TYPE**

# %%
df["Type"].value_counts()
# Out:
# Free    9989
# Paid     769
# 0          1
# Name: Type, dtype: int64

# %%
# The data includes two types of applications: free and paid. 
# In one row, the type is recorded as "nan" and the price is 0, indicating that it is a free app. 
# To handle this, the "nan" value was changed to "free."

df['Type'].fillna('Free',inplace=True)

# %%
# Verifying the results with a cross-check.

df['Type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **3) CONTENT RATING**

# %%
df["Content Rating"].value_counts()
# Out:
# Everyone           8641
# Teen               1203
# Mature 17+          496
# Everyone 10+        413
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
df[df['Content Rating'].isnull()]
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#        Size  Installs Type  Price Content Rating             Genres  \
# 10472   0.0       NaN    0    NaN            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# In some columns, the values are found to be mismatched. 
# To handle this, we will drop the entire row.

df.drop(10472, axis=0)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# **4) CURRENT VERSION**

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating  Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2     55.0
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1  20145.0
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2   4010.0
# 6803                         BT Master               FAMILY     4.3      0.0
# 7333                       Dots puzzle               FAMILY     4.0    179.0
# 7407                   Calculate My IQ               FAMILY     4.3     44.0
# 7730                            UFO-CQ                TOOLS     4.3      1.0
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.3      8.0
#
#         Size   Installs  Type  Price Content Rating             Genres  \
# 15       2.7     5000.0  Free   0.00       Everyone       Art & Design
# 1553    11.0  1000000.0  Free   0.00       Everyone   Libraries & Demo
# ...

# %%
df['Current Ver'].value_counts()
# Out:
# Varies with device    1456
# 1.0                    786
# 1.1                    258
# 1.2                    177
# 2.0                    150
#                       ...
# 7.16.8                   1
# 5.1.0 free               1
# 2.10.06                  1
# 18.0.2                   1
# 2.0.148.0                1
# Name: Current Ver, Length: 2826, dtype: int64

# %%
# The data has no specific value to replace null entries with. 
# Therefore, we will drop the 8 rows containing null values.

df=df[df['Current Ver'].notna()]
df.shape
# Out:
# (10751, 13)

# %% [markdown]
# **5) ANDROID VERSION**

# %%
df[df['Android Ver'].isnull()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#          Reviews  Size  Installs  Type  Price Content Rating  \
# 4453       230.0  11.0    1000.0  Paid   1.49       Everyone
# 4490       189.0   2.1   10000.0  Free   0.00       Everyone
# 10472  3000000.0   0.0       NaN     0    NaN            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
df['Android Ver'].value_counts()
# Out:
# 4.1 and up            2427
# 4.0.3 and up          1487
# 4.0 and up            1360
# Varies with device    1359
# 4.4 and up             975
# 2.3 and up             647
# 5.0 and up             598
# 4.2 and up             387
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             242
# 3.0 and up             237
# 2.1 and up             132
# 1.6 and up             113
# 6.0 and up              59
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              31
# 5.1 and up              24
# 1.5 and up              19
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               5
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
# There is no specific value to replace null entries with. 
# Hence, we will drop the three rows containing null values.

df=df[df['Android Ver'].notna()]
df.shape
# Out:
# (10748, 13)

# %%
# A cross-check is performed to ensure that no remaining null values exist in the data.

table=pd.DataFrame(index=df.columns)
table["datatype"]=df.dtypes
table["not null values"]=df.count()
table["null value"]=df.isnull().sum()

table
# Out:
#                datatype  not null values  null value
# App              object            10748           0
# Category         object            10748           0
# Rating          float64            10748           0
# Reviews         float64            10748           0
# Size            float64            10748           0
# Installs        float64            10748           0
# Type             object            10748           0
# Price           float64            10748           0
# Content Rating   object            10748           0
# Genres           object            10748           0
# Last Updated     object            10748           0
# Current Ver      object            10748           0
# Android Ver      object            10748           0

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Initially, we verified the data type and converted it to float. Next, we conducted a sanity check to ensure that the number of reviews was not greater than the number of installed users. We then checked for any null values and replaced them with other values where possible, such as replacing null values in the Rating column with the median value. Where replacement was not possible, such as for the content rating, current version, and Android version, we deleted the null entries.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Application Type (Univariate Analysis)

# %%
# Chart - 1 visualization code
Type_distribution = df['Type'].value_counts()
Type_distribution.plot(kind='bar')
plt.title('Type of Distribution ')
plt.ylabel('Number of Apps')
plt.xlabel('Type')
# Out:
# Text(0.5, 0, 'Type')

# %%
(values,counts)= np.unique(df["Type"], return_counts=True)
print(counts)
for index in range(len(values)):
    print(f"{values[index]}: {counts[index]}")
# Out:
# [9982  766]
# Free: 9982
# Paid: 766

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs are used to compare and contrast the size, quantity, or frequency of data between different categories or groups. They provide an easy and straightforward way to represent data visually and make it easier to compare and understand the data.
#
# As we're aware, there are only two categories of applications, free and paid. In this case, a bar chart is an effective tool for comparing these two categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The number of downloads for paid apps is generally lower compared to those for free apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# With most apps on the play store being free, users may have come to expect that apps are free to download and use. As a result, you may need to consider alternative monetization strategies, such as in-app purchases, subscriptions, or advertising.
#
# You can offer a free version of your app with limited features, and then offer in-app purchases or subscriptions for access to additional features or functionalities.

# %% [markdown]
# #### Chart - 2 Price and Rating (Bivariate Analysis)

# %%
# Chart - 2 visualization code
rcParams['figure.figsize'] = 11,8.5

sns.jointplot(x='Price', y='Rating', data=df, kind='reg')
plt.show()

# ======================
df["Price"].hist()
plt.title("Pricing Distribution For Apps")
plt.ylabel("App Count")
plt.xlabel("Price (U.S $)")
# Out:
# Text(0.5, 0, 'Price (U.S $)')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# So here we wanted to see relationship between price and ratings and joint plot is a powerful tool for visualizing the relationship between two variables in a dataset, it can be useful when you want to see both the distribution and relationship of two variables at the same time.
#
# By looking at a histogram, it is easy to understand the underlying distribution of a dataset that is why we choose histogram.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  By Looking both Graphs, we can conclude that on increasing the Price, Rating remains almost constant greater than 4
#
# Most top rated apps are optimally priced between ~1 to 30.
#
# There are only a very few apps priced above 30$
#
# But what shocking is the Apps priced above 250$ !!!

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing the relationship between pricing and ratings, you can determine the optimal price point for your app. For example, if you find that apps with higher prices tend to have higher ratings, you may want to consider pricing your app at a higher point.
#
#
# If you find that apps with higher prices tend to have higher ratings, you may want to consider a monetization strategy that includes in-app purchases or subscriptions, as this can help to increase revenue while still offering a high-quality app at a higher price point.

# %% [markdown]
# #### Chart - 3 Most Installed and Expensive App (Bivariate Analysis)

# %%
# Chart - 3 visualization code
expensive_apps = df.loc[df['Price'] >=250]

expensive_apps.loc[:, ["App", "Category"]]
# Out:
#                                  App   Category
# 4197          most expensive app (H)     FAMILY
# 4362                      💎 I'm rich  LIFESTYLE
# 4367        I'm Rich - Trump Edition  LIFESTYLE
# 5351                       I am rich  LIFESTYLE
# 5354                  I am Rich Plus     FAMILY
# 5355                   I am rich VIP  LIFESTYLE
# 5356               I Am Rich Premium    FINANCE
# 5357             I am extremely Rich  LIFESTYLE
# 5358                      I am Rich!    FINANCE
# 5359              I am rich(premium)    FINANCE
# 5362                   I Am Rich Pro     FAMILY
# 5364  I am rich (Most expensive app)    FINANCE
# 5366                       I Am Rich     FAMILY
# 5369                       I am Rich    FINANCE
# 5373              I AM RICH PRO PLUS    FINANCE

# %%
expensive_apps["Installs"].groupby(expensive_apps["App"]).sum()
# Out:
# App
# I AM RICH PRO PLUS                  1000.0
# I Am Rich                          10000.0
# I Am Rich Premium                  50000.0
# I Am Rich Pro                       5000.0
# I am Rich                           5000.0
# I am Rich Plus                     10000.0
# I am Rich!                          1000.0
# I am extremely Rich                 1000.0
# I am rich                         100000.0
# I am rich (Most expensive app)      1000.0
# I am rich VIP                      10000.0
# I am rich(premium)                  5000.0
# I'm Rich - Trump Edition           10000.0
# most expensive app (H)               100.0
# 💎 I'm rich                         10000.0
# Name: Installs, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To swiftly investigate apps priced above 250$, one can quickly examine them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Of the most costly apps, the most widely installed is "I am Rich," which is the most popular among them.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing the most installed apps, you can gain insights into the types of apps that are most popular with users. This information can be used to inform the development of your own app, as well as to identify potential gaps in the market that your app could fill.
#
# Knowing which apps are most popular, you can position your app to be similar or complementary to those apps. This can help to increase the visibility of your app and make it more appealing to users.

# %% [markdown]
# #### Chart - 4 Category Vs Price (Bivariate Analysis)

# %%
# Chart - 4 visualization code
sns.scatterplot(x="Category", y="Price",data=df)

plt.xticks(rotation=90)
plt.figure(figsize=(14,9))
plt.rcParams['figure.figsize'] = 11,8.5

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we wanted to know the most expensive apps belong to which category and Scatter plots are particularly useful when you want to identify outliers in the data, which can be done by looking for points that fall far away from the general trend.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Ignoring the catogories with price > 100$
#
# Medical and Family apps are the most expensive. Some medical apps extend even upto 80$.
#
# All other apps are priced under 30$.
#
# Shocking..... all game apps are reasonably priced below 20$.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If your business is developing a medical app, positioning it as a premium product with a higher price point may be more effective, as it suggests that the app is of high quality and provides valuable features.
#
# By developing a medical app that is unique and offers features that are not found in other medical apps, you can differentiate your app from the competition, which can justify a higher price point.

# %% [markdown]
# #### Chart - 5 Size Vs Rating (Bivariate Analysis)

# %%
# Chart - 5 visualization code
#app distribution according to size rating and type
plt.figure(figsize=(12,6))
sns.scatterplot(df['Size'],
                df['Rating'],
                hue=df['Type'],
                s=100)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are useful for visualizing the relationship between two variables. They can help identify patterns or trends in the data, such as a positive or negative correlation.
#
# Scatter plots can be used to identify outliers or unusual data points. They can help to spot unusual trends or patterns that may be missed when working with other types of plots.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Generally on increasing Rating, Size of App also increases. But this is not always true ie. for higher Rating, their is constant Size. Thus we can conclude that their is positive correlation between Size and Rating.
#
# Most top rated apps are optimally sized between ~2MB to ~40MB - neither too light nor too heavy.
#
# Most of the have high rating as more than 3 even if its size is too high or too low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# You could use this information for App Design and Development to optimize the size of your app by focusing on the features that are most important to users and cutting out unnecessary features. This could help improve the rating of your app while keeping it at a manageable size.
#
# You could use this information to set the price for your app based on its size, with smaller apps costing less. This could be especially useful if you have found that smaller apps tend to have higher ratings.

# %% [markdown]
# #### Chart - 6 Size Vs Rating For Paid Apps (Multivariate Analysis)

# %%
# Chart - 6 visualization code
paid_apps = df[df['Price'] > 0]

# %%
g = sns.JointGrid(data=paid_apps, x="Rating", y="Size", space=0, ratio=17)
sns.set_theme(style="white", color_codes=True)

g.plot_joint(sns.scatterplot, size=paid_apps["Rating"], sizes=(30, 120),
             color="g", alpha=.6, legend=False)
g.plot_marginals(sns.rugplot, height=1, color="g", alpha=.6)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:1740: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A joint grid in Python is a type of plot that is used to visualize the relationship between two variables. It combines both a scatter plot and a histogram to show the distribution of one variable along the x-axis and the distribution of the other variable along the y-axis.
#
# We choose a joint grid in Python because we want to see both the relationship between two variables and the distribution of each variable individually. The scatter plot shows the relationship between the two variables, while the histograms on the sides show the distribution of each variable. This can be useful for identifying patterns or trends in the data that may not be immediately obvious from looking at a scatter plot or histogram alone.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Majority of the paid apps that are highly rated have small sizes. This means that most paid apps are designed and developed to specific functionalities and hence are not bulky.
#
# Users prefer to pay for apps that are light-weighted. A paid app that is bulky may not perform well in the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# You could use this information to optimize the size of your app by focusing on the features that are most important to users and cutting out unnecessary features. This could help improve the rating of your app while keeping it at a manageable size.
#
# You can target users who are looking for apps that are smaller in size, this could be done by using keywords related to small-size apps in your app's title and description.

# %% [markdown]
# #### Chart - 7 Min Price App (Univariate Analysis)

# %%
# Chart - 7 visualization code
print("$ {}".format(paid_apps["Price"].min()))
# Out:
# $ 0.99

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To determine the minimum price for paid apps, one would need to check.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The minimum price for paid apps has been found to be 0.99$.

# %% [markdown]
# #### Chart - 8 Rating (Univariate Analysis)

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10,5))
sns.countplot(x='Rating',data=df)
plt.title('RATING DISTRIBUTION')
plt.ylabel('Number of Apps')
plt.xticks(rotation=90)
plt.xlabel('Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For Frequency visualization. Count plots are used to visualize the frequency of unique values in a categorical data set. They can help to identify the most common values or categories in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of the apps are rated between three to five stars, with the highest rating being 4.3 stars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# You can use this information to analyze the rating of your competitors apps and adjust your strategy accordingly.
#
# You can use the rating of your app to analyze the reviews, and identify the most common reasons why users have given your app a specific rating.

# %% [markdown]
# #### Chart - 9 REVIEWS PER RATING (Bivariate Analysis)

# %%
# Chart - 9 visualization code
rating_df = df.groupby('Rating').sum().reset_index()
print(f"Average Rating {df['Rating'].mean()}")
plt.figure(figsize=(10,5))
plt.plot(rating_df['Rating'],rating_df['Reviews'])
plt.title('REVIEW PER RATING')
plt.ylabel('Reviews')
plt.xlabel('Rating')
# Out:
# Average Rating 4.2056103461109045
# Text(0.5, 0, 'Rating')

# %%
print(f"Average Rating {df['Rating'].mean()}")
# Out:
# Average Rating 4.2056103461109045

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For visualizing reviews data that changes over rating, we choose this simple line graph. Line graphs can be used to identify trends in the data, such as upward or downward patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# you may notice that apps with a high rating also have a large number of reviews, or that apps with a low rating have a small number of reviews.
#
# Generally, most apps do well with an average rating of 4.2 or above with highest reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Use the data analysis to inform your competitive analysis. For example, if you notice that apps with a high rating also have a large number of reviews, it may be beneficial to focus on acquiring more reviews for your app in order to improve its rating.

# %% [markdown]
# #### Chart - 10 Category and Reviews (Bivariate Analysis)

# %%
# Chart - 10 visualization code
category_list = list(df['Category'].unique())
category_review = []
for i in category_list:
    x = df[df['Category'] == i]
    if(len(x)!=0):
        review = sum(x.Reviews)/len(x)
        category_review.append(review)
    else:
        review = sum(x.Reviews)
        category_review.append(review)
#sorting
df_category_reviews = pd.DataFrame({'category': category_list,'review':category_review})
new_index = (df_category_reviews['review'].sort_values(ascending=False)).index.values
sorted_df =df_category_reviews.reindex(new_index)

# visualization
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_df['category'], y=sorted_df['review'])
plt.xticks(rotation=80)
plt.xlabel("Category")
plt.ylabel("Reviews")
plt.title("Category and Reviews")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We want to visualize the distribution of data that is divided into discrete categories.
#
# Bar plots are often used to display data that is divided into discrete categories, such as the number of apps who belong to different category groups, the number of reviews in different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The categories with the highest number of reviews are Social and Communication, followed by Games, Photography, and Video Players.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing the number of reviews per category, a business can identify which categories of apps are the most popular among users. This information can be used to determine which categories of apps to develop or invest in, in order to reach a wider audience.
#
# By analyzing the reviews, a business can identify problem areas in their app, such as bugs, usability issues, or missing features. Addressing these issues can lead to more positive reviews and higher ratings, which can help to increase downloads and revenue.

# %% [markdown]
# #### Chart - 11 Category and Installs (Bivariate Analysis)

# %%
# Chart - 11 visualization code
category_list = list(df['Category'].unique())
category_install = []
for i in category_list:
    x = df[df['Category'] == i]
    if(len(x)!=0):
        install = sum(x.Installs)/len(x)
        category_install.append(install)
    else:
        install = sum(x.Installs)
        category_install.append(install)
        
#sorting
df_category_install = pd.DataFrame({'category': category_list,'install':category_install})
new_index = (df_category_install['install'].sort_values(ascending=False)).index.values
sorted_df =df_category_install.reindex(new_index)

# visualization
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_df['category'], y=sorted_df['install'])
plt.xticks(rotation=80)
plt.xlabel("Category")
plt.ylabel("Install")
plt.title("Category and Install")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We want to create a stacked bar chart, showing the contribution of different sub-categories to the total value.
# Here we wanted to compare the relative magnitudes (Installs) of different values(Category) so we choose the bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, it is apparent that the Communication category has the highest number of downloads, followed by Social and Video Players.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing the installs per category, a business can identify trends in app usage and popularity. This information can be used to predict future trends and make informed decisions about product development and marketing
#
# By analyzing the installs, a business can identify problem areas in their app, such as low retention rate, low conversion rate, or poor user experience. Addressing these issues can lead to more installs and revenue.

# %% [markdown]
# #### Chart - 12 Content Rating (Univariate Analysis)

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10,7))
sns.countplot(data=df, x='Content Rating')
plt.xticks(rotation=80)
plt.title('Content Rating',color = 'blue',fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plots are used to visualize the frequency of unique values in a categorical data set. They can help to identify the most common values or categories in the data. So for quickly visualizing the distribution of a categorical variable (Content rating) we choose count plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As depicted in the bar chart, apps with the "Everyone" content rating make up the majority, followed by those with a "Teen" rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing the content rating of apps, a business can identify the age group that the app is intended for. This information can be used to tailor the app's content and functionality to the target age group, increasing the chances of success.
#
# By analyzing the content rating of apps, a business can create marketing campaigns that target specific age groups or audiences, increasing the chances of success.

# %% [markdown]
# #### Chart - 13 Category (Univariate Analysis)

# %%
# Chart - 13 visualization code
temp = df['Category'].value_counts().reset_index()
plt.figure(figsize=(12,12))
ax = plt.subplot(111)
plt.pie(x = temp['Category'], labels= temp['index'],autopct= '%1.1f%%')
plt.legend()
ax.legend(bbox_to_anchor=(1.4, 1))
plt.show()

# %%
top = np.array(df.Category.value_counts().reset_index()['index'])
print('Most occuring categories are \n',top[:6])
# Out:
# Most occuring categories are
#  ['FAMILY' 'GAME' 'TOOLS' 'MEDICAL' 'BUSINESS' 'PRODUCTIVITY']

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted to show hierarchical relationships of categorical data between the percentage of categories that come from different regions.
#
# So showing the relative size of different categories a pie chart found to be useful.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Family and Game apps have the strongest market presence.
#
# Notably, Tools, Business, and Medical apps are also gaining traction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the categories that are popular on the play store can help a business identify potential markets for their own app. For example, if a business sees that there is a high demand for family and game apps, they may choose to develop a productivity app to target that market.
#
# A business can use this information to identify gaps in the market and develop apps that fill those gaps.

# %% [markdown]
# #### Chart - 14 - Most occuring categories Rating (Bivariate Analysis)

# %%
# Chart - 14 visualization code
plt.figure(figsize= (15,10))
plt.suptitle("Ratings of Different Categories",fontsize = 25)

plt.subplot(2,3,1)
sns.kdeplot(df[df['Category'] == 'FAMILY']['Rating'], shade = True)
plt.title('Rating of FAMILY Apps')

plt.subplot(2,3,2)
sns.kdeplot(df[df['Category'] == 'GAME']['Rating'], shade = True)
plt.title('Rating of GAME Apps')


plt.subplot(2,3,3)
sns.kdeplot(df[df['Category'] == 'TOOLS']['Rating'], shade = True)
plt.title('Rating of TOOLS Apps')


plt.subplot(2,3,4)
sns.kdeplot(df[df['Category'] == 'MEDICAL']['Rating'], shade = True)
plt.title('Rating of MEDICAL Apps')


plt.subplot(2,3,5)
sns.kdeplot(df[df['Category'] == 'BUSINESS']['Rating'], shade = True)
plt.title('Rating of BUSINESS Apps')


plt.subplot(2,3,6)
sns.kdeplot(df[df['Category'] == 'PRODUCTIVITY']['Rating'], shade = True)
plt.title('Rating of PRODUCTIVITY Apps')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Kernel Density Estimate (KDE) plot
#
# A KDE plot is a smoothed version of a histogram, which is used to visualize the probability density function of a continuous variable.
#
# So we choose this seaborn KDE plot, here the function takes in a data set of rating of most occuring categories and creates a plot of the estimated probability density of the data. I

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above Kernel Density Estimate (KDE) plot suggests that the categories 'Family', 'Game', 'Tools', 'Medical', 'Business', and 'Productivity' have almost identical ratings of 4.0 - 4.7.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Examining the most used and highly rated categories on the play store can give a business insight into what their competitors are doing.
#
# A business can use most used and highly rated categories information to identify potential partners, such as other app developers or companies that offer complementary products.

# %% [markdown]
# #### Chart - 15 - Reviews Vs Rating (Bivariate Analysis)

# %%
# Chart - 15 visualization code
print("Number of Apps with more than 1M reviews",df[df['Reviews'] > 1000000].shape[0])
print("\nTop 20 apps with most reviews: \n",df[df['Reviews'] > 1000000].sort_values(by = 'Reviews', ascending = False).head(20)['App'])

# %%
print('for all apsps more tahn 1M reviews')
sns.jointplot(x='Reviews',y='Rating',data =df[df['Reviews']>100000],color='darkgreen')
plt.show()

print('for apps below 1M reviews')
sns.jointplot(x='Reviews',y='Rating',data =df[df['Reviews']<100000],color ='darkorange')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# So here we wanted to see relationship between reviews and ratings and joint plot is a powerful tool for visualizing the relationship between two variables in a dataset, it can be useful when you want to see both the distribution and relationship of two variables at the same time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Apps with the most reviews are likely to have higher ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive reviews and high ratings can be used in marketing materials to attract new users and increase app visibility on the play store.
#
# A business can identify users who leave positive reviews and high ratings, as these users may be potential influencers who can help promote the app.

# %% [markdown]
# #### Chart - 16 Price Distribution (Univariate Analysis)

# %%
# Chart - 16 visualization code
plt.figure(figsize=(10,7))
sns.kdeplot(df[df['Type'] == 'Paid']['Price'], color = 'red', shade = True)
plt.xlabel('Prices of Apps')
plt.title('Pricing Distribution of Paid Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# you can use Kernel Density Estimation (KDE) plots in python when you are working with univariate datasets and want to visualize the distribution of the data, especially when the data has a complex or non-standard distribution, when working with small datasets, when comparing multiple datasets or when comparing a dataset to a known distribution, or when identifying outliers in the data.
# So here we are working with the univariate dataset which is price of app and wanted to see the density distribution for that reason we choose the KDE plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be noted that the majority of paid apps are reasonably priced.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing the density distribution of app prices, a business can get an idea of the general price range for apps in their desired category. This can help them determine a pricing strategy that will be competitive within the market.

# %% [markdown]
# #### Chart - 17 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
df.corr()

# %%
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# When dealing with multiple variables, it can be useful to visualize the relationship between them in a single plot. A correlation heatmap allows you to easily identify which variables are strongly correlated and which are not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Price is slightly negatively correlated with the Rating, Reviews, and Installs. This means that as the prices of the app increases, the average rating, total number of reviews and Installs fall slightly.
#
# The Rating is slightly positively correlated with the Installs and Reviews column. This indicates that as the the average user rating increases, the app installs and number of reviews also increase.

# %% [markdown]
# #### Chart - 18 - Pair Plot

# %%
# Pair Plot visualization code
# Create the pair plot
sns.pairplot(df)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pairplot function creates a scatter plot matrix of all the numeric variables in the DataFrame, with histograms along the diagonal. By default, it uses a scatter plot to show the relationship between two variables
#
# pairplot is a type of scatter plot that displays the relationship between multiple variables in a dataset. It plots each variable against all the other variables, producing a matrix of scatter plots. Each cell in the matrix represents the relationship between two variables, making it easier to identify patterns, relationships, and correlations between the variables. Pairplots can help visualize the distribution of data and reveal any outliers, which can be important in understanding the data and informing further analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that:
#
# Most of the Paid Apps have Rating around 4.
#
# As the number of installation increases the number of reviews of the particaular app also increases.

# %% [markdown]
# ## **SENTIMENT ANALYSIS**

# %% [markdown]
# ### Dataset First View

# %%
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
df2.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Plya Store Dataset size")
print("Rows {} Columns {}".format(df2.shape[0], df2.shape[1]))
# Out:
# Plya Store Dataset size
# Rows 64295 Columns 5

# %% [markdown]
# ### Dataset Information

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df2[df2.duplicated()])
# Out:
# 33616

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df2.isnull().sum())
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(df2.isnull(), cbar=False)

# %% [markdown]
# #### Understanding Your Variables

# %%
# Dataset Columns
df2.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
df2.describe(include='all')
# Out:
#                         App Translated_Review Sentiment  Sentiment_Polarity  \
# count                 64295             37427     37432        37432.000000
# unique                 1074             27994         3                 NaN
# top     Angry Birds Classic              Good  Positive                 NaN
# freq                    320               247     23998                 NaN
# mean                    NaN               NaN       NaN            0.182146
# std                     NaN               NaN       NaN            0.351301
# min                     NaN               NaN       NaN           -1.000000
# 25%                     NaN               NaN       NaN            0.000000
# 50%                     NaN               NaN       NaN            0.150000
# 75%                     NaN               NaN       NaN            0.400000
# max                     NaN               NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **CUSTOMER REVIEW DATA**
#
# This file contains the result of the sentiment analysis conducted by the dataset creator. It has 64,295 rows of data with the following columns:
#
# App : Name of the app.
#
# Translated_Review: Either the original review in English, or a translated version if the orignal review is in another language.
#
# Sentiment: The result of the sentiment analysis conducted on a review. The value is either Positive, Neutral, or Negative.
#
# Sentiment_Polarity: A value indicating the positivity or negativity of the sentiment, values range from -1 (most negative) to 1 (most positive).
#
# Sentiment_Subjectivity: A value from 0 to 1 indicating the subjectivity of the review. Lower values indicate the review is based on factual information, and higher values indicate the review is based on personal or public opinions or judgements.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df2.columns.tolist():
  print("No. of unique values in ",i,"is",df2[i].nunique(),".")
# Out:
# No. of unique values in  App is 1074 .
# No. of unique values in  Translated_Review is 27994 .
# No. of unique values in  Sentiment is 3 .
# No. of unique values in  Sentiment_Polarity is 5410 .
# No. of unique values in  Sentiment_Subjectivity is 4474 .

# %% [markdown]
# ### Data Wrangling

# %%
df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
nan_columns = []
nan_values = []

for column in df2.columns:
    nan_columns.append(column)
    nan_values.append(df2[column].isnull().sum())

fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(nan_columns, nan_values)
plt.title("Number of Nan values present in all columns")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Nan values present in all columns')

# %%
## Merge a slice of the original dataset that contains App names and Types with corresponding apps in this dataset.

# %%
from pandas._libs.algos import diff_2d
df2= pd.merge(df2, df[["App","Type"]] , how='inner', on="App")

# Drop null values from sentiment data
df2 = df2.dropna()

df2.shape
# Out:
# (72605, 6)

# %% [markdown]
# In order to obtain the values for the app column, we merge the dataset of the Play Store app reviews on the app and type columns using an inner join, then remove the missing values from the sentiment data.

# %% [markdown]
# ### Data Vizualization

# %% [markdown]
# #### **Free vs Paid**

# %%
## Now that we have our dataframe containing the data we need to answer the analysis, let's see how many apps of each type we have

# %%
(values,counts)= np.unique(df2["Type"], return_counts=True)
print(counts)
for index in range(len(values)):
    print(f"{values[index]}: {counts[index]}")
# Out:
# [71823   782]
# Free: 71823
# Paid: 782

# %%
# create a dataframe for each app type
free_apps = df2[df2["Type"] == "Free"]
paid_apps = df2[df2["Type"] == "Paid"]

# %%
# Return normalized values (percentages) of each value's occurrence & display them
print("Free Apps - Sentiment Percentage \n" + "-"*30 + "\n{}\n\n".format(free_apps['Sentiment'].value_counts(normalize=True) * 100))
print("Paid Apps - Sentiment Percentage \n" + "-"*30 +"\n{}".format(paid_apps['Sentiment'].value_counts(normalize=True) * 100))
# Out:
# Free Apps - Sentiment Percentage
# ------------------------------
# Positive    63.446250
# Negative    25.089456
# Neutral     11.464294
# Name: Sentiment, dtype: float64
#
#
# Paid Apps - Sentiment Percentage
# ------------------------------
# Positive    80.051151
# Negative    14.578005
# Neutral      5.370844
# Name: Sentiment, dtype: float64

# %% [markdown]
# The percentage of positive sentiments in paid apps is significantly higher than that of free apps.

# %%
# Reset index, then drop the old index column when it is moved to the right as a new column
paid_apps = paid_apps.reset_index().drop(columns=["index"])
free_apps = free_apps.reset_index().drop(columns=["index"])

# Generate a list of random indexes applicable to free_apps
random_indexes = np.random.choice(len(free_apps)-1, len(paid_apps), replace=False)

# Shorten free_apps to the same size of paid_apps & using a random selection
free_apps = free_apps.iloc[random_indexes]

# Reset index of free_apps
free_apps = free_apps.reset_index().drop(columns=["index"])

# %%
# Generate values & counts for Sentiment columns in our dataframes & put them in dictionaries
val_ct_free = np.unique(free_apps['Sentiment'],return_counts=True)
free_data = {value: count for value, count in zip(val_ct_free[0],val_ct_free[1])}

val_ct_paid = np.unique(paid_apps['Sentiment'],return_counts=True)
paid_data = {value: count for value, count in zip(val_ct_paid[0],val_ct_paid[1])}


# Put values and counts each in a different variable for use in plots, taken from dictionaries
free_names = list(free_data.keys())
free_values = list(free_data.values())
paid_names = list(paid_data.keys())
paid_values = list(paid_data.values())


# Create a figure containing plots for each app type, sharing the y-axis for comparison
fig, axs = plt.subplots(1, 2, figsize=(10, 6),sharey=True)
axs[0].bar(free_names, free_values)
axs[0].set_title("Free App Sentiments")
axs[1].bar(paid_names, paid_values)
axs[1].set_title("Paid App Sentiments")
plt.show()

# %% [markdown]
# ##### Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The percentage of positive sentiments in paid apps is significantly higher than that of free apps.
#
# This information can be used in a business by considering charging for their app, as paid apps tend to have a higher percentage of positive sentiments. Additionally, this information can also be used to justify a higher price point for a paid app by highlighting its higher perceived value compared to free alternatives. However, it's important to note that charging for an app may also limit the potential user base, so it should be weighed against other factors such as target audience and market demand before making a decision. This information can also be used to guide marketing and promotion efforts, highlighting the positive sentiments associated with paid apps to attract users who are more likely to have a positive experience.

# %% [markdown]
# #### **Sentiment Polarity**

# %%
polarity_paid = paid_apps["Sentiment_Polarity"]
polarity_free = free_apps["Sentiment_Polarity"]

# Plot two histograms showing sentiment polarity of each app type
plt.figure(figsize=(14,5))
plt.hist(polarity_paid,  color="green",alpha=.7, label="Paid Apps") 
plt.hist(polarity_free, color="red",alpha=.4, label="Free Apps")

plt.title('Sentiment Polarity Distribution For Free & Paid Apps')
plt.xlabel('Sentiment Polarity')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# When we look at this graph, we find that there is more neutral polarity in free apps, as shown by the larger red region just above the 0.00 on the x axis.
#
# However there is a more extreme positive polarity for free apps, as seen on the x axis in the range of 0.5 to 1.00.
#
# When it comes to Paid apps, the majority of opinions fall somewhere between 0 and 0.5.
#
# While some sentiments are exceptionally positive, none fall below -0.5, suggesting greater overall satisfaction with paid apps and demonstrating a minimum cap for negative sentiments.

# %% [markdown]
# #### **Sentiment Analysis with Category**

# %%
# First we merge the Category & App of 1st data set to App column in 2nd data set
category_df = pd.merge(df2, df[["App","Category"]] , how='inner', on="App")

# Drop all nan values
category_df =category_df.dropna()

# %%
from matplotlib.ticker import PercentFormatter

# %%
f = plt.figure(figsize=(15,8))
ax = f.add_subplot(1,1,1)

sns.histplot(
    category_df,
    x="Category", hue="Sentiment",
    bins=34,
    ax=ax, 
    stat="count",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    legend=True
    )


ax.set_title("Sentiment Analysis Based on Category",fontsize=15,fontweight='bold')
plt.xticks(rotation='vertical')
ax.set_xlabel("Category",fontsize=13)
ax.set_ylabel("Review Counts",fontsize=13)

plt.gca().yaxis.set_major_formatter(PercentFormatter(20000))
sns.set(style="ticks")
plt.grid()
plt.show()

# %% [markdown]
# Apps in the categories of Family, Sports, and Health & Fitness have the strongest performance, with over 50% of reviews being positive.

# %% [markdown]
# ##### Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This information can be used in a business by focusing on developing or promoting apps in the other categories. By targeting these categories, a company may be able to benefit from the high demand for such apps and increase their chances of receiving positive reviews, leading to higher user engagement and potential revenue. Additionally, understanding the market trends and user preferences can inform product development strategies and marketing campaigns.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Business objectives are a written explanation of your goals as a business. Business objectives usually have to do with the most important operating factors of a company's success, such as revenue, operations, productivity and growth. To be most successful, some companies find that a business objective needs to be specific, measurable, attainable and time-based. Large and small businesses alike might find value in developing written business objectives.
#
# The goal of this analysis project is to help the client achieve success in the play store by providing them with valuable insights and recommendations. The focus should be on creating apps in untapped categories, offering free content for a wider audience, regularly updating the app to meet changing user preferences, and listening to user feedback to enhance the app's functionality. By implementing these strategies, the client can increase their chances of receiving high installations and attain their business objectives.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1) Average rating of (active) apps on Google Play Store is 4.3.
#
# 2) Users prefer to pay for apps that are light-weighted. Thus, a paid app that is bulky may not perform well in the market.
#
# 3) Most of the top rated apps are optimally sized between ~2MB to ~40MB - neither too light nor too heavy.
#
# 4) Most of the top rated apps are optimally priced between 1$$ - 20$ - neither too cheap nor too expensive.
#
# 5) Medical and Family apps are the most expensive and even extend upto 80$.
#
# 6) Users tend to download a given app more if it has been reviewed by a large number of people.
#
# 7) Paid apps have a slightly higher number of favourable reviews than free apps.
#
# 8) Free apps get more negative and neutral feedback, suggesting a wider range of opinions.
#
# 9) When it comes to free apps, users are more pessimistic and harsh than when it comes to paid apps.
#
# 10) More than half users rate Family, Sports and Health & Fitness apps positively. Apps for games and social media get mixed reviews,
# with 50 percent positive and 50 percent negative responses.
#
# 11) The percentage of positive sentiments in paid apps is significantly higher than that of free apps

# %% [markdown]
# In conclusion, the Exploratory Data Analysis (EDA) on the Google Playstore data provided valuable insights into the app market. We were able to identify patterns and trends in the data, such as the dominance of the Family and Games categories in terms of number of apps and the average rating of apps. We also observed that the majority of apps had a rating of around 4.3, indicating a relatively high level of satisfaction among users. Additionally, we found that free apps had a higher number of installs compared to paid apps. These findings can be useful for app developers and businesses looking to enter the market, as well as for users looking for apps to download. Overall, the EDA on the Google Playstore data was informative and highlighted important trends in the app market.

# %% [markdown]
# In conclusion, the Exploratory Data Analysis (EDA) on sentiment analysis of Google Playstore data provided valuable insights into the customer feedback on apps. We were able to observe the overall sentiment of customer reviews, and found that the majority of reviews had a positive sentiment. We also examined the relationship between the sentiment of customer reviews and the rating of the app, and found that there was a positive correlation between the two.  These findings can be useful for app developers and businesses looking to improve their apps and customer satisfaction. Overall, the EDA on sentiment analysis of the Google Playstore data was informative and highlighted important trends in customer feedback on apps.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
